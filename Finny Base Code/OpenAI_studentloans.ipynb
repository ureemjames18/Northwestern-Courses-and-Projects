# %% [markdown]
# # Import the Libraries and Files

# %%
# # install the llama_index module
# !pip install llama_index
# !pip install openai
# !pip install cohere
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 917.6/917.6 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 19.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.4/221.4 kB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 62.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
# ...

# %%
# Import the libraries

from llama_index import GPTVectorStoreIndex, SimpleDirectoryReader, Document, VectorStoreIndex
import os
import pandas as pd
from IPython.display import display

# %%
from google.colab import drive
drive.mount('/content/gdrive')

file_path = r'/content/gdrive/MyDrive/Data/student_loans.xlsx'
df = pd.read_excel(file_path, sheet_name='Sheet1')


os.environ["OPENAI_API_KEY"] = ""

documents = SimpleDirectoryReader('/content/gdrive/MyDrive/Data/info').load_data()
# Out:
# Mounted at /content/gdrive

# %%
# df['Text']


# from_xlsx = df['Text'].tolist()

# for i in range(len(from_xlsx)):
#   from_xlsx[i] = from_xlsx[i].replace("\n", " ")

# documents = [Document(t) for t in from_xlsx]

# %%
documents
# Out:
# [Document(id_='9f52cc82-e72d-4f29-b27f-4ddf94f61362', embedding=None, metadata={'file_path': '/content/gdrive/MyDrive/Data/info/student_loans_non_edited.txt', 'file_name': 'student_loans_non_edited.txt', 'file_type': 'text/plain', 'file_size': 74258, 'creation_date': '2023-12-02', 'last_modified_date': '2023-12-02', 'last_accessed_date': '2023-12-02'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, hash='5b785a25765205f53c497ba6f149cdfff4303fea30957b90008e81ff0dcb5b22', text='In the United States, student loans are a form of financial aid intended to help students access higher education. In 2018, 70 percent of higher education graduates had used loans to cover some or all of their expenses. With notable exceptions, student loans must be repaid, in contrast
# ...

# %%
index = GPTVectorStoreIndex.from_documents(documents)
index.storage_context.persist(persist_dir="generated_index.json")
# Out:
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# # Create an infinite loop asking for user input and then breaking out of the loop when the response is empty
# while True:
#   query = input("Ask a question: ")
#   if not query:
#     print("Goodbye")
#     break
# # query the index with the question and print the result
#   result = index.query(query)
#   print(result)

while True:
  query = input("Ask a question: ")
  if not query:
    print('Goodbye. Please consult your school counselor or visit https://studentaid.gov for more information.')
    break
  query_engine = index.as_query_engine()
  response = query_engine.query(query)
  print(response)
# Out:
# If you are unable to pay back your loans, there are options available to you. One option is to consider an income-driven repayment plan, which allows borrowers to cap their monthly payments at a percentage of their disposable income. Another option is to explore loan forgiveness programs, which may cancel or reduce your loan balance under certain circumstances. Additionally, you can contact your loan servicer to discuss alternative repayment options or to request a temporary suspension of payments through forbearance or deferment. It's important to communicate with your loan servicer and explore all available options to find a solution that works for your financial situation.
# ...
